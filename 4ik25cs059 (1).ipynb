# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes_prediction_dataset.csv")

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
heart.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 heart.tail()
#
# NameError: name 'heart' is not defined

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  str
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  str
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.head(10)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# ...

# %%
df.tail(20)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99980  Female  52.0             0              0           never  27.32
# 99981    Male  26.0             0              0         No Info  24.08
# 99982  Female  80.0             0              0           never  30.04
# 99983  Female  21.0             0              0         No Info  27.32
# 99984    Male  80.0             1              0         No Info  20.96
# 99985    Male  25.0             0              0         No Info  27.32
# 99986  Female  63.0             0              0           never  29.01
# 99987  Female  23.0             0              0           never  17.87
# 99988    Male  19.0             0              0         No Info  25.75
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99991    Male  22.0             0              0         current  29.65
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='str')

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.rows
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %%
df.age
# Out:
# 0        80.0
# 1        54.0
# 2        28.0
# 3        36.0
# 4        76.0
#          ...
# 99995    80.0
# 99996     2.0
# 99997    66.0
# 99998    24.0
# 99999    57.0
# Name: age, Length: 100000, dtype: float64

# %%
df["bmi"].unique()
# Out:
# array([25.19, 27.32, 23.45, ..., 59.42, 44.39, 60.52], shape=(4247,))

# %%
df.value_counts()
# Out:
# gender  age   hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# Female  80.0  0             0              No Info          27.32  6.5          159                  0           9
#                                                                    6.2          90                   0           9
#                                                                    4.0          85                   0           8
#                                                                                 160                  0           7
#                                                                                 158                  0           7
#                                                                                                                 ..
#         36.0  0             0              No Info          24.60  4.8          145                  0           1
# ...

# %%
df["age"].mean()
# Out:
# np.float64(41.885856)

# %%
df["age"].median()
# Out:
# np.float64(43.0)

# %%
df["age"].min()
# Out:
# np.float64(0.08)

# %%
df["blood_glucose_level"].mean()
# Out:
# np.float64(138.05806)

# %%
df["blood_glucose_level"].median()
# Out:
# np.float64(140.0)

# %%
df["blood_glucose_level"].max()
# Out:
# np.int64(300)

# %%
df["age"].max()
# Out:
# np.float64(80.0)

# %%
df.dtypes
# Out:
# gender                     str
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history            str
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.size
# Out:
# 900000

# %%
df.ndim
# Out:
# 2

# %%
df.empty
# Out:
# False

# %%
df.sample(10)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99574  Female  34.0             0              0           never  24.72
# 52101  Female  55.0             0              0           never  27.32
# 26150  Female  53.0             0              0           never  21.30
# 34179    Male  52.0             0              0            ever  27.36
# 25900    Male  50.0             0              0          former  22.55
# 37606    Male  68.0             0              0            ever  28.03
# 80689    Male   4.0             0              0         No Info  27.32
# 65252  Female  55.0             0              0         No Info  27.32
# 67929    Male  17.0             0              0         No Info  21.71
# 22697    Male  40.0             0              0         No Info  19.76
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99574          4.5                  126         0
# 52101          5.7                  145         0
# ...

# %%
df.describe(include="age")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.describe(include="age")
#
# NameError: name 'df' is not defined

# %%
df.describe(include="age")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.describe(include="age")
#
# NameError: name 'df' is not defined
